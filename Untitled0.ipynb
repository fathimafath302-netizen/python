# %% [markdown]
# <a href="https://colab.research.google.com/github/fathimafath302-netizen/python/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a=int(input('enter a no'))
b=int(in)

# %%
a=int(input('enter a no'))
b=int(input('enter a no'))
if a>b:
  print('a is big')
else:
  print('b is big')
# Out:
# enter a no5
# enter a no7
# b is big

# %%
a=int(input('enter a mark'))
if a>=35:
  print('passed')
else:
  print('fail')
# Out:
# enter a mark25
# fail

# %%
a=int(input('enter no'))
if a%2==0:
  print('even')
else:
  print('odd')
# Out:
# enter no2
# even

# %%
a=int(input('enter an age'))
if a>18:
      print('eligible')
else:
      print('not eligible')
# Out:
# enter an age55
# eligible

# %%
a=int(input('enter a no'))
if a>0:
      print('positive')
elif a<0:
      print('negative')
else:
      print('zero')
# Out:
# enter a no5
# positive

# %%
a=int(input('enter an no'))
if a>10:
    print('no is greater')
else:
      print('lessthan')
# Out:
# enter an no50
# no is greater

# %%
f=input('first name')
l=input('last name')
fullname=f+l
print(fullname)
# Out:
# first namehidha
# last namesherin
# hidha sherin

# %%
a=int(input('maths'))
b=int(input('english'))
c=int(input('phy'))
d=int(input('che'))
e=int(input('mala'))
total=(a+b+c+d+e)/5
print(total)
# Out:
# maths10
# english20
# phy30
# che40
# mala50
# 110.0

# %%
a=int(input('maths'))
b=int(input('english'))
c=int(input('phy'))
d=int(input('che'))
e=int(input('mala'))
total=a+b+c+d+e
print(total)
# Out:
# maths10
# english20
# phy30
# che40
# mala50
# 150

# %%
a=int(input('enter radius'))
pi=3.14
area=pi*a*a
print(area)
# Out:
# enter radius2
# 12.56

# %%
l=int(input('enter length'))
b=int(input('enter breadth'))
area=l*b
print(area)
# Out:
# enter length5
# enter breadth4
# 20

# %%
a=int(input('enter a no'))
b=int(input('enter a 2no'))
c=int(input('enter 3 no'))
print(a+b+c)
# Out:
# enter a no2
# enter a 2no3
# enter 3 no1
# 6

# %%
n=input('name')
a=int(input('age'))
print(n,a)
# Out:
# nameminhal
# age19
# minhal 19

# %%
a=int(input('enter 1st no.'))
b=int(input('enter 2nd no.'))
print(a)
print(b)
print(a+b)
# Out:
# enter 1st no.5
# enter 2nd no.5
# 5
# 5
# 10

# %%
n=input('name')
a=int(input('age'))
print(n,a)
# Out:
# namehidha
# age18
# hidha 18

# %%
a=input('name')
b=int(input('age'))
print(a,b)
# Out:
# namenoora
# age18
# noora 18

# %%
n=input('name')
a=int(input('age'))
print(n,a)
# Out:
# namefathima
# age18
# fathima 18

# %%
a=input('enter a name')
print(a)
# Out:
# enter a namehidha
# hidha

# %%
fruits="orange"
print(fruits)
print(fruits[0])
print(fruits[-1])
print(len(fruits))
# Out:
# orange
# o
# e
# 6

# %%
c="19"
print(c)
print(type(c))
# Out:
# 19
# <class 'str'>

# %%
b=18
print(b)
print(type(b))
# Out:
# 18
# <class 'int'>

# %%
a="fathima"
print(a)
print(type(a))
# Out:
# fathima
# <class 'str'>
